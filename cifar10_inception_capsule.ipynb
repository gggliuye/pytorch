# %%
# %matplotlib inline

# %%
from __future__ import print_function, division

import time
import numpy as np

from plot_utils import plot_confusion_matrix, imshow, plot_losses
import torch as th
from torch.autograd import Variable
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

# %%
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

# %%
from torch.utils.data.sampler import SubsetRandomSampler

n_training_samples = 20000 # Max: 50 000 - n_val_samples
n_val_samples = 5000
n_test_samples = 5000

train_sampler = SubsetRandomSampler(np.arange(n_training_samples, dtype=np.int64))
val_sampler = SubsetRandomSampler(np.arange(n_training_samples, n_training_samples + n_val_samples, dtype=np.int64))
test_sampler = SubsetRandomSampler(np.arange(n_test_samples, dtype=np.int64))

# %%
num_workers = 2
test_batch_size = 4

#data augmentation
transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
     transforms.RandomRotation(10),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_set = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=test_batch_size, sampler=train_sampler,
                                          num_workers=num_workers)

test_set = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=test_batch_size, sampler=test_sampler,
                                         num_workers=num_workers)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class LinearClassifier(nn.Module):
    """
    Linear Classifier
    """
    def __init__(self):
        super(LinearClassifier, self).__init__()
        self.linear = nn.Linear(32 * 32 * 3, 10)

    def forward(self, x):
        # Flatten input 3x32x32 -> 3072
        x = x.view(x.size(0), -1)
        return self.linear(x)

# %%
import torch.optim as optim

def createLossAndOptimizer(net, learning_rate=0.001):
    # it combines softmax with negative log likelihood loss
    criterion = nn.CrossEntropyLoss()  
    #optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    return criterion, optimizer

# %%
def get_train_loader(batch_size):
    return torch.utils.data.DataLoader(train_set, batch_size=batch_size, sampler=train_sampler,
                                              num_workers=num_workers)

# Use larger batchsize for validation to speed up computation
val_loader = torch.utils.data.DataLoader(train_set, batch_size=128, sampler=val_sampler,
                                          num_workers=num_workers)

# %%
def train(net, batch_size, n_epochs, learning_rate):
    """
    Train a neural network and print statistics of the training
    
    :param  net: (PyTorch Neural Network)
    :param batch_size: (int)
    :param n_epochs: (int)  Number of iterations on the training set
    :param learning_rate: (float) learning rate used by the optimizer
    """
    print("===== HYPERPARAMETERS =====")
    print("batch_size=", batch_size)
    print("n_epochs=", n_epochs)
    print("learning_rate=", learning_rate)
    print("=" * 30)
    
    train_loader = get_train_loader(batch_size)
    n_minibatches = len(train_loader)

    criterion, optimizer = createLossAndOptimizer(net, learning_rate)
    # Init variables used for plotting the loss
    train_history = []
    val_history = []

    training_start_time = time.time()
    best_error = np.inf
    best_model_path = "best_model.pth"

    for epoch in range(n_epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        print_every = n_minibatches // 10
        start_time = time.time()
        total_train_loss = 0
        
        for i, data in enumerate(train_loader, 0):
            # get the inputs
            inputs, labels = data

            # wrap them in Variable
            inputs, labels = Variable(inputs), Variable(labels)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.data[0]
            total_train_loss += loss.data[0]

            # print every 10th of epoch
            if (i + 1) % (print_every + 1) == 0:    
                print("Epoch {}, {:d}% \t train_loss: {:.2f} took: {:.2f}s".format(
                      epoch + 1, int(100 * (i + 1) / n_minibatches), running_loss / print_every,
                      time.time() - start_time))
                running_loss = 0.0
                start_time = time.time()

        train_history.append(total_train_loss / len(train_loader))

        total_val_loss = 0
        ## Do a pass on the validation set
        for inputs, labels in val_loader:
            # Wrap Tensors in Variables
            inputs, labels = Variable(inputs), Variable(labels)
            # Forward pass
            predictions = net(inputs)
            val_loss = criterion(predictions, labels)
            total_val_loss += val_loss.data[0]
            
        val_history.append(total_val_loss / len(val_loader))
        # Save model that performs best on validation set
        if total_val_loss < best_error:
            best_error = total_val_loss
            th.save(net.state_dict(), best_model_path)

        print("Validation loss = {:.2f}".format(total_val_loss / len(val_loader)))

    print("Training Finished, took {:.2f}s".format(time.time() - training_start_time))
    
    # Load best model
    net.load_state_dict(th.load(best_model_path))
    
    return train_history, val_history

# %%
def dataset_accuracy(net, data_loader, name=""):
    correct = 0
    total = 0
    for data in data_loader:
        images, labels = data
        outputs = net(Variable(images))
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum()
    accuracy = 100 * correct / total
    print('Accuracy of the network on the {} {} images: {:.2f} %'.format(total, name, accuracy))

def train_set_accuracy(net):
    dataset_accuracy(net, train_loader, "train")

def val_set_accuracy(net):
    dataset_accuracy(net, val_loader, "validation")  
    
def test_set_accuracy(net):
    dataset_accuracy(net, test_loader, "test")

def compute_accuracy(net):
    train_set_accuracy(net)
    val_set_accuracy(net)
    test_set_accuracy(net)
    
print("Computing accuracy...")
compute_accuracy(net)
# Out:
# Computing accuracy...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e9ae0031b996> in <module>()
#      26
#      27 print("Computing accuracy...")
# ---> 28 compute_accuracy(net)
#
# NameError: name 'net' is not defined

# %%
def accuracy_per_class(net):
    n_classes = 10
    class_correct = list(0. for i in range(n_classes))
    class_total = list(0. for i in range(n_classes))
    # (real, predicted)
    confusion_matrix = np.zeros((n_classes, n_classes), dtype=np.int64)

    for data in test_loader:
        images, labels = data
        outputs = net(Variable(images))
        _, predicted = torch.max(outputs.data, 1)
        c = (predicted == labels).squeeze()
        for i in range(test_batch_size):
            confusion_matrix[labels[i], predicted[i]] += 1
            label = labels[i]
            class_correct[label] += c[i]
            class_total[label] += 1

    print("{:<10} {:^10}".format("Class", "Accuracy (%)"))
    for i in range(n_classes):
        print('{:<10} {:^10.2f}'.format(
            classes[i], 100 * class_correct[i] / class_total[i]))
    return confusion_matrix

confusion_matrix = accuracy_per_class(net)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-95c2eeb67aaf> in <module>()
#      23     return confusion_matrix
#      24
# ---> 25 confusion_matrix = accuracy_per_class(net)
#
# NameError: name 'net' is not defined

# %%
def get_output_size(in_size, kernel_size, stride=1, padding=0):
    """
    Get the output size given all the parameters of the convolution
    :param in_size: (int) input size
    :param kernel_size: (int)
    :param stride: (int)
    :param paddind: (int)
    :return: (int)
    """
    return int((in_size - kernel_size + 2 * padding) / stride) + 1

# %%
class MyConvolutionalNetwork(nn.Module):
    def __init__(self):
        super(MyConvolutionalNetwork, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 18, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        #### START CODE: ADD NEW LAYERS ####
        #IN_V1
        self.v1pool1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.v1conv1 = nn.Conv2d(18, 16, kernel_size=1, stride=1, padding=0)
        
        self.v1conv2 = nn.Conv2d(18, 8, kernel_size=1, stride=1, padding=0)
        self.v1conv22 = nn.Conv2d(8, 16, kernel_size=5, stride=1, padding=2)
        
        self.v1conv3 = nn.Conv2d(18, 48, kernel_size=1, stride=1, padding=0)
        self.v1conv32 = nn.Conv2d(48, 64, kernel_size=3, stride=1, padding=1)
        
        self.v1conv4 = nn.Conv2d(18, 32, kernel_size=1, stride=1, padding=0)
        
        self.pool2 = nn.MaxPool2d(kernel_size=3, stride=3, padding=1)
        #IN_V2 6 6 128   6 6 256
        self.v2pool1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.v2conv1 = nn.Conv2d(128, 32, kernel_size=1, stride=1, padding=0)
        
        self.v2conv2 = nn.Conv2d(128, 16, kernel_size=1, stride=1, padding=0)
        self.v2conv22 = nn.Conv2d(16, 32, kernel_size=5, stride=1, padding=2)
        
        self.v2conv3 = nn.Conv2d(128, 96, kernel_size=1, stride=1, padding=0)
        self.v2conv32 = nn.Conv2d(96, 128, kernel_size=3, stride=1, padding=1)
        
        self.v2conv4 = nn.Conv2d(128, 64, kernel_size=1, stride=1, padding=0)
        
        self.pool3 = nn.MaxPool2d(kernel_size=3, stride=3, padding=0)
        #IN_V3 2 2 256 2 2 512
        self.v3pool1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.v3conv1 = nn.Conv2d(256, 64, kernel_size=1, stride=1, padding=0)
        
        self.v3conv2 = nn.Conv2d(256, 32, kernel_size=1, stride=1, padding=0)
        self.v3conv22 = nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2)
        
        self.v3conv3 = nn.Conv2d(256, 192, kernel_size=1, stride=1, padding=0)
        self.v3conv32 = nn.Conv2d(192, 256, kernel_size=3, stride=1, padding=1)
        
        self.v3conv4 = nn.Conv2d(256, 128, kernel_size=1, stride=1, padding=0)
        
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        # Size of the output of the last convolution:
        self.flattened_size = 512
        ### END CODE ###
        
        self.fc1 = nn.Linear(self.flattened_size, 10)

    def forward(self, x):
        """
        Forward pass,
        x shape is (batch_size, 3, 32, 32)
        (color channel first)
        in the comments, we omit the batch_size in the shape
        """
        # shape : 3x32x32 -> 18x32x32
        x = F.relu(self.conv1(x))
        # 18x32x32 -> 18x16x16
        x = self.pool1(x)
        #IN_V1
        x1 = self.v1pool1(x)
        x1 = self.v1conv1(x1)
        
        x2 = self.v1conv2(x)
        x2 = self.v1conv22(x2)
        
        x3 = self.v1conv3(x)
        x3 = self.v1conv32(x3)
        
        x4 = self.v1conv4(x)

        x = F.relu(torch.cat((x1,x2,x3,x4),1))
        x = self.pool2(x)
        
        #IN_V2
        x1 = self.v2pool1(x)
        x1 = self.v2conv1(x1)
        
        x2 = self.v2conv2(x)
        x2 = self.v2conv22(x2)
        
        x3 = self.v2conv3(x)
        x3 = self.v2conv32(x3)
        
        x4 = self.v2conv4(x)
        
        x = F.relu(torch.cat((x1,x2,x3,x4),1))
        x = self.pool3(x)
        #IN_V3
        x1 = self.v3pool1(x)
        x1 = self.v3conv1(x1)
        
        x2 = self.v3conv2(x)
        x2 = self.v3conv22(x2)
        
        x3 = self.v3conv3(x)
        x3 = self.v3conv32(x3)
        
        x4 = self.v3conv4(x)
        
        x = F.relu(torch.cat((x1,x2,x3,x4),1))
        x = self.pool4(x)

        
        # Check the output size
        output_size = np.prod(x.size()[1:])
        assert output_size == self.flattened_size,\
                "self.flattened_size is invalid {} != {}".format(output_size, self.flattened_size)
        
        # 18x16x16 -> 4608
        x = x.view(-1, self.flattened_size)
        # 4608 -> 64
        x = F.dropout(x, training=self.training)
        # 64 -> 10
        x = self.fc1(x)
        return x

# %%
def squash(s, dim = 2):
    s1 = torch.sum(s**2, dim, keepdim=True)
    s2 = torch.sqrt(s)
    out = (s1/(1.0 + s1))*(s/s2)
    return out

def softmax(input, dim=1):
    input_size = input.size()

    trans_input = input.transpose(dim, len(input_size) - 1)
    trans_size = trans_input.size()
    input_2d = trans_input.contiguous().view(-1, trans_size[-1])
    soft_max_2d = F.softmax(input_2d)
    soft_max_nd = soft_max_2d.view(*trans_size)

    return soft_max_nd.transpose(dim, len(input_size) - 1)

# %%
class Capsule(nn.Module):
    def __init__(self):
        super(Capsule, self).__init__()
        self.convs = nn.ModuleList([
            nn.Conv2d(256, 32 , 9, 2) for u in range(8)
        ])

    def forward(self, x):
        
        #input size 32*32*256 output size 12*12*32
        #8 units in total
        temp = [self.convs[i](x) for i,l in enumerate(self.convs)]
        #stack the 8 units to shape 128*8*32*12*12
        x = torch.stack(temp, dim = 1)
        batchsize = x.size(0)
        #into shape 128*8*4608
        #into shape 128*8*4608
        x = x.view(batchsize, 8, -1)
        #use squash function
        x = squash(x, dim=2)
        return x

class Capsule_routing(nn.Module):
    def __init__(self):
        # 1*4608*10*16*8
        # inchannel num_unit unit_size in_unit
        super(Capsule_routing, self).__init__()
        self.weight = nn.Parameter(torch.randn(1,4608,10,16,8))

    def forward(self, x):
        batchsize = x.size(0)
        # output shape 128*4608*8
        x = x.transpose(1,2)
        # output shape 128*4608*10*8*1
        x = torch.stack([x]*10, dim=2).unsqueeze(4)
        # change weight size to 128*4608*10*16*8
        batch_weight = torch.cat([self.weight]*batchsize, dim=0)
        # u_hat shape 128*4608*10*16*1
        u_hat = torch.matmul(batch_weight, x)
        bij = Variable(torch.zeros(1,4608,10,1))
        num_routing = 3
        for i in range(num_routing):
            cij = softmax(bij, dim=2)
            cij = torch.cat([cij]*batchsize,dim=0).unsqueeze(4)
            sj = (cij*u_hat).sum(dim=1,keepdim=True)
            #cij 128*4608*10*1*1  sj 128*1*10*16*1
            vj = squash(sj , dim=3)
            vj1 = torch.cat([vj]*4608,dim=1)
            uvj1 = torch.matmul(u_hat.transpose(3,4), vj1).squeeze(4).mean(dim=0,keepdim=True)
            
            bij = bij + uvj1
        #return 128*10*16
        x = vj.squeeze(1).squeeze(3)
        x = x.sum(2)
        return x.squeeze(2)


class MyCapNetwork(nn.Module):
    def __init__(self):
        super(MyCapNetwork, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 256, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=1, padding=0)
        #### START CODE: ADD NEW LAYERS ####
        #Capsule Network
        self.cap = Capsule()
        self.caprouting = Capsule_routing()
        
    def forward(self, x):
        """
        Forward pass,
        x shape is (batch_size, 3, 32, 32)
        (color channel first)
        in the comments, we omit the batch_size in the shape
        """
        # shape : 3x32x32 -> 18x32x32
        x = F.relu(self.conv1(x))
        # 18x32x32 -> 18x16x16
        x = self.pool1(x)
        #IN_V1
        x = self.cap(x)
        x = self.caprouting(x)

        return x

# %%
net = MyCapNetwork()
train_history, val_history = train(net, batch_size=128, n_epochs=1, learning_rate=0.001)
# Out:
# ===== HYPERPARAMETERS =====
# batch_size= 128
# n_epochs= 1
# learning_rate= 0.001
# ==============================
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-43-af367113bc34> in <module>()
#       1 net = MyCapNetwork()
# ----> 2 train_history, val_history = train(net, batch_size=128, n_epochs=1, learning_rate=0.001)
#
# <ipython-input-10-e372c5cee07f> in train(net, batch_size, n_epochs, learning_rate)
#      44
#      45             # forward + backward + optimize
# ---> 46             outputs = net(inputs)
#      47             loss = criterion(outputs, labels)
#      48             loss.backward()
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# <ipython-input-42-9ca70b561aec> in forward(self, x)
#      79         x = self.pool1(x)
#      80         #IN_V1
# ---> 81         x = self.cap(x)
#      82         x = self.caprouting(x)
#      83
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# <ipython-input-42-9ca70b561aec> in forward(self, x)
#      10         #input size 32*32*256 output size 12*12*32
#      11         #8 units in total
# ---> 12         temp = [self.convs[i](x) for i,l in enumerate(self.convs)]
#      13         #stack the 8 units to shape 128*8*32*12*12
#      14         x = torch.stack(temp, dim = 1)
#
# <ipython-input-42-9ca70b561aec> in <listcomp>(.0)
#      10         #input size 32*32*256 output size 12*12*32
#      11         #8 units in total
# ---> 12         temp = [self.convs[i](x) for i,l in enumerate(self.convs)]
#      13         #stack the 8 units to shape 128*8*32*12*12
#      14         x = torch.stack(temp, dim = 1)
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     252     def forward(self, input):
#     253         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 254                         self.padding, self.dilation, self.groups)
#     255
#     256
#
# ~/.local/lib/python3.5/site-packages/torch/nn/functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      50     f = ConvNd(_pair(stride), _pair(padding), _pair(dilation), False,
#      51                _pair(0), groups, torch.backends.cudnn.benchmark, torch.backends.cudnn.enabled)
# ---> 52     return f(input, weight, bias)
#      53
#      54
#
# RuntimeError: $ Torch: not enough memory: you tried to allocate 1GB. Buy new RAM! at /pytorch/torch/lib/TH/THGeneral.c:270

# %%
net = MyConvolutionalNetwork()
train_history, val_history = train(net, batch_size=128, n_epochs=40, learning_rate=0.001)
# Out:
# ===== HYPERPARAMETERS =====
# batch_size= 128
# n_epochs= 40
# learning_rate= 0.001
# ==============================
# Epoch 1, 10% 	 train_loss: 2.43 took: 61.92s
# Epoch 1, 20% 	 train_loss: 2.30 took: 57.77s
# Epoch 1, 30% 	 train_loss: 2.15 took: 52.24s
# Epoch 1, 40% 	 train_loss: 2.10 took: 48.89s
# Epoch 1, 50% 	 train_loss: 2.03 took: 45.02s
# Epoch 1, 61% 	 train_loss: 1.99 took: 44.74s
# Epoch 1, 71% 	 train_loss: 1.89 took: 44.74s
# Epoch 1, 81% 	 train_loss: 1.85 took: 44.69s
# Epoch 1, 91% 	 train_loss: 1.86 took: 44.96s
# Validation loss = 1.67
# Epoch 2, 10% 	 train_loss: 1.74 took: 46.20s
# Epoch 2, 20% 	 train_loss: 1.67 took: 45.15s
# Epoch 2, 30% 	 train_loss: 1.65 took: 45.08s
# Epoch 2, 40% 	 train_loss: 1.64 took: 44.93s
# Epoch 2, 50% 	 train_loss: 1.59 took: 45.18s
# Epoch 2, 61% 	 train_loss: 1.61 took: 44.83s
# Epoch 2, 71% 	 train_loss: 1.58 took: 46.66s
# Epoch 2, 81% 	 train_loss: 1.47 took: 44.85s
# Epoch 2, 91% 	 train_loss: 1.54 took: 44.96s
# Validation loss = 1.40
# Epoch 3, 10% 	 train_loss: 1.47 took: 46.00s
# Epoch 3, 20% 	 train_loss: 1.47 took: 44.89s
# Epoch 3, 30% 	 train_loss: 1.41 took: 44.95s
# Epoch 3, 40% 	 train_loss: 1.46 took: 44.86s
# Epoch 3, 50% 	 train_loss: 1.44 took: 45.33s
# Epoch 3, 61% 	 train_loss: 1.38 took: 44.89s
# Epoch 3, 71% 	 train_loss: 1.43 took: 44.89s
# Epoch 3, 81% 	 train_loss: 1.36 took: 45.00s
# Epoch 3, 91% 	 train_loss: 1.41 took: 45.15s
# Validation loss = 1.27
# Epoch 4, 10% 	 train_loss: 1.26 took: 46.05s
# Epoch 4, 20% 	 train_loss: 1.33 took: 44.95s
# Epoch 4, 30% 	 train_loss: 1.35 took: 45.00s
# Epoch 4, 40% 	 train_loss: 1.31 took: 44.99s
# Epoch 4, 50% 	 train_loss: 1.31 took: 45.29s
# Epoch 4, 61% 	 train_loss: 1.29 took: 45.06s
# Epoch 4, 71% 	 train_loss: 1.29 took: 44.97s
# Epoch 4, 81% 	 train_loss: 1.28 took: 45.15s
# Epoch 4, 91% 	 train_loss: 1.30 took: 45.13s
# Validation loss = 1.17
# Epoch 5, 10% 	 train_loss: 1.21 took: 45.96s
# Epoch 5, 20% 	 train_loss: 1.17 took: 44.79s
# Epoch 5, 30% 	 train_loss: 1.23 took: 44.88s
# Epoch 5, 40% 	 train_loss: 1.14 took: 44.86s
# Epoch 5, 50% 	 train_loss: 1.18 took: 45.23s
# Epoch 5, 61% 	 train_loss: 1.15 took: 44.76s
# Epoch 5, 71% 	 train_loss: 1.15 took: 44.89s
# Epoch 5, 81% 	 train_loss: 1.17 took: 45.18s
# Epoch 5, 91% 	 train_loss: 1.16 took: 44.91s
# Validation loss = 1.07
# Epoch 6, 10% 	 train_loss: 1.11 took: 45.98s
# Epoch 6, 20% 	 train_loss: 1.10 took: 44.95s
# Epoch 6, 30% 	 train_loss: 1.14 took: 44.98s
# Epoch 6, 40% 	 train_loss: 1.10 took: 44.89s
# Epoch 6, 50% 	 train_loss: 1.11 took: 45.29s
# Epoch 6, 61% 	 train_loss: 1.10 took: 44.96s
# Epoch 6, 71% 	 train_loss: 1.10 took: 44.95s
# Epoch 6, 81% 	 train_loss: 1.13 took: 45.15s
# Epoch 6, 91% 	 train_loss: 1.09 took: 45.06s
# Validation loss = 1.01
# Epoch 7, 10% 	 train_loss: 1.03 took: 46.08s
# Epoch 7, 20% 	 train_loss: 1.02 took: 44.98s
# Epoch 7, 30% 	 train_loss: 1.03 took: 45.04s
# Epoch 7, 40% 	 train_loss: 1.07 took: 44.99s
# Epoch 7, 50% 	 train_loss: 1.05 took: 45.36s
# Epoch 7, 61% 	 train_loss: 1.03 took: 45.02s
# Epoch 7, 71% 	 train_loss: 1.02 took: 44.96s
# Epoch 7, 81% 	 train_loss: 1.07 took: 45.28s
# Epoch 7, 91% 	 train_loss: 1.04 took: 45.02s
# Validation loss = 1.04
# Epoch 8, 10% 	 train_loss: 0.98 took: 45.87s
# Epoch 8, 20% 	 train_loss: 0.98 took: 45.00s
# Epoch 8, 30% 	 train_loss: 0.96 took: 45.03s
# Epoch 8, 40% 	 train_loss: 0.99 took: 44.93s
# Epoch 8, 50% 	 train_loss: 0.97 took: 45.34s
# Epoch 8, 61% 	 train_loss: 0.98 took: 44.86s
# Epoch 8, 71% 	 train_loss: 0.92 took: 44.97s
# Epoch 8, 81% 	 train_loss: 0.97 took: 45.30s
# Epoch 8, 91% 	 train_loss: 0.98 took: 44.87s
# Validation loss = 0.95
# Epoch 9, 10% 	 train_loss: 0.95 took: 45.88s
# Epoch 9, 20% 	 train_loss: 0.85 took: 44.95s
# Epoch 9, 30% 	 train_loss: 0.93 took: 45.01s
# Epoch 9, 40% 	 train_loss: 0.91 took: 44.99s
# Epoch 9, 50% 	 train_loss: 0.91 took: 45.24s
# Epoch 9, 61% 	 train_loss: 0.90 took: 44.94s
# Epoch 9, 71% 	 train_loss: 0.95 took: 44.88s
# Epoch 9, 81% 	 train_loss: 0.93 took: 45.24s
# Epoch 9, 91% 	 train_loss: 0.96 took: 45.02s
# Validation loss = 0.94
# Epoch 10, 10% 	 train_loss: 0.89 took: 46.07s
# Epoch 10, 20% 	 train_loss: 0.90 took: 44.90s
# Epoch 10, 30% 	 train_loss: 0.87 took: 44.90s
# Epoch 10, 40% 	 train_loss: 0.93 took: 44.90s
# Epoch 10, 50% 	 train_loss: 0.90 took: 45.18s
# Epoch 10, 61% 	 train_loss: 0.87 took: 45.11s
# Epoch 10, 71% 	 train_loss: 0.86 took: 45.18s
# Epoch 10, 81% 	 train_loss: 0.92 took: 45.53s
# Epoch 10, 91% 	 train_loss: 0.88 took: 45.13s
# Validation loss = 0.86
# Epoch 11, 10% 	 train_loss: 0.80 took: 46.84s
# Epoch 11, 20% 	 train_loss: 0.86 took: 45.13s
# Epoch 11, 30% 	 train_loss: 0.82 took: 45.06s
# Epoch 11, 40% 	 train_loss: 0.81 took: 45.00s
# Epoch 11, 50% 	 train_loss: 0.87 took: 45.34s
# Epoch 11, 61% 	 train_loss: 0.85 took: 45.04s
# Epoch 11, 71% 	 train_loss: 0.83 took: 45.07s
# Epoch 11, 81% 	 train_loss: 0.86 took: 45.40s
# Epoch 11, 91% 	 train_loss: 0.85 took: 45.07s
# Validation loss = 0.85
# Epoch 12, 10% 	 train_loss: 0.81 took: 46.20s
# Epoch 12, 20% 	 train_loss: 0.83 took: 45.42s
# Epoch 12, 30% 	 train_loss: 0.79 took: 45.38s
# Epoch 12, 40% 	 train_loss: 0.78 took: 45.22s
# Epoch 12, 50% 	 train_loss: 0.86 took: 45.51s
# Epoch 12, 61% 	 train_loss: 0.80 took: 45.44s
# Epoch 12, 71% 	 train_loss: 0.83 took: 45.35s
# Epoch 12, 81% 	 train_loss: 0.81 took: 45.61s
# Epoch 12, 91% 	 train_loss: 0.78 took: 45.26s
# Validation loss = 0.87
# Epoch 13, 10% 	 train_loss: 0.74 took: 46.34s
# Epoch 13, 20% 	 train_loss: 0.78 took: 45.27s
# Epoch 13, 30% 	 train_loss: 0.77 took: 45.29s
# Epoch 13, 40% 	 train_loss: 0.77 took: 45.37s
# Epoch 13, 50% 	 train_loss: 0.77 took: 45.34s
# Epoch 13, 61% 	 train_loss: 0.78 took: 45.25s
# Epoch 13, 71% 	 train_loss: 0.77 took: 45.34s
# Epoch 13, 81% 	 train_loss: 0.81 took: 45.54s
# Epoch 13, 91% 	 train_loss: 0.80 took: 45.17s
# Validation loss = 0.83
# Epoch 14, 10% 	 train_loss: 0.71 took: 46.40s
# Epoch 14, 20% 	 train_loss: 0.72 took: 45.38s
# Epoch 14, 30% 	 train_loss: 0.76 took: 45.19s
# Epoch 14, 40% 	 train_loss: 0.79 took: 45.48s
# Epoch 14, 50% 	 train_loss: 0.73 took: 45.26s
# Epoch 14, 61% 	 train_loss: 0.77 took: 45.24s
# Epoch 14, 71% 	 train_loss: 0.75 took: 45.20s
# Epoch 14, 81% 	 train_loss: 0.75 took: 45.55s
# Epoch 14, 91% 	 train_loss: 0.80 took: 45.19s
# Validation loss = 0.82
# Epoch 15, 10% 	 train_loss: 0.72 took: 46.51s
# Epoch 15, 20% 	 train_loss: 0.76 took: 45.44s
# Epoch 15, 30% 	 train_loss: 0.76 took: 45.28s
# Epoch 15, 40% 	 train_loss: 0.75 took: 45.57s
# Epoch 15, 50% 	 train_loss: 0.70 took: 45.37s
# Epoch 15, 61% 	 train_loss: 0.73 took: 45.26s
# Epoch 15, 71% 	 train_loss: 0.68 took: 45.35s
# Epoch 15, 81% 	 train_loss: 0.68 took: 45.79s
# Epoch 15, 91% 	 train_loss: 0.74 took: 45.31s
# Validation loss = 0.80
# Epoch 16, 10% 	 train_loss: 0.69 took: 46.28s
# Epoch 16, 20% 	 train_loss: 0.70 took: 45.31s
# Epoch 16, 30% 	 train_loss: 0.71 took: 45.37s
# Epoch 16, 40% 	 train_loss: 0.70 took: 45.52s
# Epoch 16, 50% 	 train_loss: 0.71 took: 45.41s
# Epoch 16, 61% 	 train_loss: 0.70 took: 45.34s
# Epoch 16, 71% 	 train_loss: 0.74 took: 45.32s
# Epoch 16, 81% 	 train_loss: 0.72 took: 45.59s
# Epoch 16, 91% 	 train_loss: 0.69 took: 45.29s
# Validation loss = 0.88
# Epoch 17, 10% 	 train_loss: 0.71 took: 46.21s
# Epoch 17, 20% 	 train_loss: 0.68 took: 45.31s
# Epoch 17, 30% 	 train_loss: 0.66 took: 45.26s
# Epoch 17, 40% 	 train_loss: 0.67 took: 45.70s
# Epoch 17, 50% 	 train_loss: 0.69 took: 45.41s
# Epoch 17, 61% 	 train_loss: 0.72 took: 45.48s
# Epoch 17, 71% 	 train_loss: 0.66 took: 45.30s
# Epoch 17, 81% 	 train_loss: 0.71 took: 45.54s
# Epoch 17, 91% 	 train_loss: 0.72 took: 45.30s
# Validation loss = 0.83
# Epoch 18, 10% 	 train_loss: 0.65 took: 46.26s
# Epoch 18, 20% 	 train_loss: 0.66 took: 45.18s
# Epoch 18, 30% 	 train_loss: 0.67 took: 45.12s
# Epoch 18, 40% 	 train_loss: 0.65 took: 45.48s
# Epoch 18, 50% 	 train_loss: 0.71 took: 45.13s
# Epoch 18, 61% 	 train_loss: 0.68 took: 45.24s
# Epoch 18, 71% 	 train_loss: 0.69 took: 45.51s
# Epoch 18, 81% 	 train_loss: 0.65 took: 45.23s
# Epoch 18, 91% 	 train_loss: 0.66 took: 45.14s
# Validation loss = 0.78
# Epoch 19, 10% 	 train_loss: 0.62 took: 46.10s
# Epoch 19, 20% 	 train_loss: 0.61 took: 45.33s
# Epoch 19, 30% 	 train_loss: 0.59 took: 45.22s
# Epoch 19, 40% 	 train_loss: 0.63 took: 45.53s
# Epoch 19, 50% 	 train_loss: 0.65 took: 45.25s
# Epoch 19, 61% 	 train_loss: 0.67 took: 45.50s
# Epoch 19, 71% 	 train_loss: 0.67 took: 45.66s
# Epoch 19, 81% 	 train_loss: 0.68 took: 45.17s
# Epoch 19, 91% 	 train_loss: 0.62 took: 45.28s
# Validation loss = 0.78
# Epoch 20, 10% 	 train_loss: 0.58 took: 45.99s
# Epoch 20, 20% 	 train_loss: 0.58 took: 45.20s
# Epoch 20, 30% 	 train_loss: 0.62 took: 44.97s
# Epoch 20, 40% 	 train_loss: 0.64 took: 45.37s
# Epoch 20, 50% 	 train_loss: 0.61 took: 44.98s
# Epoch 20, 61% 	 train_loss: 0.67 took: 45.08s
# Epoch 20, 71% 	 train_loss: 0.65 took: 45.45s
# Epoch 20, 81% 	 train_loss: 0.62 took: 45.17s
# Epoch 20, 91% 	 train_loss: 0.59 took: 45.18s
# Validation loss = 0.80
# Epoch 21, 10% 	 train_loss: 0.58 took: 46.10s
# Epoch 21, 20% 	 train_loss: 0.56 took: 47.29s
# Epoch 21, 30% 	 train_loss: 0.60 took: 45.20s
# Epoch 21, 40% 	 train_loss: 0.59 took: 45.55s
# Epoch 21, 50% 	 train_loss: 0.61 took: 45.24s
# Epoch 21, 61% 	 train_loss: 0.60 took: 45.18s
# Epoch 21, 71% 	 train_loss: 0.62 took: 45.57s
# Epoch 21, 81% 	 train_loss: 0.64 took: 45.19s
# Epoch 21, 91% 	 train_loss: 0.62 took: 45.29s
# Validation loss = 0.77
# Epoch 22, 10% 	 train_loss: 0.54 took: 46.08s
# Epoch 22, 20% 	 train_loss: 0.54 took: 45.30s
# Epoch 22, 30% 	 train_loss: 0.56 took: 45.41s
# Epoch 22, 40% 	 train_loss: 0.53 took: 45.37s
# Epoch 22, 50% 	 train_loss: 0.59 took: 45.33s
# Epoch 22, 61% 	 train_loss: 0.62 took: 45.29s
# Epoch 22, 71% 	 train_loss: 0.58 took: 45.71s
# Epoch 22, 81% 	 train_loss: 0.58 took: 45.22s
# Epoch 22, 91% 	 train_loss: 0.64 took: 47.21s
# Validation loss = 0.83
# Epoch 23, 10% 	 train_loss: 0.59 took: 46.48s
# Epoch 23, 20% 	 train_loss: 0.53 took: 45.24s
# Epoch 23, 30% 	 train_loss: 0.56 took: 45.51s
# Epoch 23, 40% 	 train_loss: 0.54 took: 45.32s
# Epoch 23, 50% 	 train_loss: 0.60 took: 45.26s
# Epoch 23, 61% 	 train_loss: 0.57 took: 45.29s
# Epoch 23, 71% 	 train_loss: 0.59 took: 45.53s
# Epoch 23, 81% 	 train_loss: 0.59 took: 45.35s
# Epoch 23, 91% 	 train_loss: 0.64 took: 45.36s
# Validation loss = 0.81
# Epoch 24, 10% 	 train_loss: 0.59 took: 46.25s
# Epoch 24, 20% 	 train_loss: 0.63 took: 45.36s
# Epoch 24, 30% 	 train_loss: 0.54 took: 45.68s
# Epoch 24, 40% 	 train_loss: 0.56 took: 45.48s
# Epoch 24, 50% 	 train_loss: 0.58 took: 47.71s
# Epoch 24, 61% 	 train_loss: 0.55 took: 45.43s
# Epoch 24, 71% 	 train_loss: 0.57 took: 45.52s
# Epoch 24, 81% 	 train_loss: 0.60 took: 45.39s
# Epoch 24, 91% 	 train_loss: 0.55 took: 45.40s
# Validation loss = 0.84
# Epoch 25, 10% 	 train_loss: 0.51 took: 46.18s
# Epoch 25, 20% 	 train_loss: 0.57 took: 45.07s
# Epoch 25, 30% 	 train_loss: 0.56 took: 45.49s
# Epoch 25, 40% 	 train_loss: 0.55 took: 45.09s
# Epoch 25, 50% 	 train_loss: 0.53 took: 45.04s
# Epoch 25, 61% 	 train_loss: 0.55 took: 45.13s
# Epoch 25, 71% 	 train_loss: 0.57 took: 45.34s
# Epoch 25, 81% 	 train_loss: 0.55 took: 47.24s
# Epoch 25, 91% 	 train_loss: 0.56 took: 45.22s
# Validation loss = 0.75
# Epoch 26, 10% 	 train_loss: 0.55 took: 46.78s
# Epoch 26, 20% 	 train_loss: 0.57 took: 45.15s
# Epoch 26, 30% 	 train_loss: 0.55 took: 45.64s
# Epoch 26, 40% 	 train_loss: 0.50 took: 45.17s
# Epoch 26, 50% 	 train_loss: 0.57 took: 45.12s
# Epoch 26, 61% 	 train_loss: 0.53 took: 45.51s
# Epoch 26, 71% 	 train_loss: 0.50 took: 45.19s
# Epoch 26, 81% 	 train_loss: 0.55 took: 45.19s
# Epoch 26, 91% 	 train_loss: 0.57 took: 45.30s
# Validation loss = 0.76
# Epoch 27, 10% 	 train_loss: 0.51 took: 45.97s
# Epoch 27, 20% 	 train_loss: 0.52 took: 45.11s
# Epoch 27, 30% 	 train_loss: 0.55 took: 45.43s
# Epoch 27, 40% 	 train_loss: 0.48 took: 45.12s
# Epoch 27, 50% 	 train_loss: 0.49 took: 45.22s
# Epoch 27, 61% 	 train_loss: 0.51 took: 45.65s
# Epoch 27, 71% 	 train_loss: 0.55 took: 45.25s
# Epoch 27, 81% 	 train_loss: 0.52 took: 45.21s
# Epoch 27, 91% 	 train_loss: 0.53 took: 45.17s
# Validation loss = 0.83
# Epoch 28, 10% 	 train_loss: 0.51 took: 46.15s
# Epoch 28, 20% 	 train_loss: 0.49 took: 45.30s
# Epoch 28, 30% 	 train_loss: 0.51 took: 45.64s
# Epoch 28, 40% 	 train_loss: 0.46 took: 45.23s
# Epoch 28, 50% 	 train_loss: 0.51 took: 45.27s
# Epoch 28, 61% 	 train_loss: 0.55 took: 45.58s
# Epoch 28, 71% 	 train_loss: 0.54 took: 45.32s
# Epoch 28, 81% 	 train_loss: 0.49 took: 45.34s
# Epoch 28, 91% 	 train_loss: 0.51 took: 45.24s
# Validation loss = 0.83
# Epoch 29, 10% 	 train_loss: 0.51 took: 45.96s
# Epoch 29, 20% 	 train_loss: 0.50 took: 45.23s
# Epoch 29, 30% 	 train_loss: 0.50 took: 45.49s
# Epoch 29, 40% 	 train_loss: 0.54 took: 45.15s
# Epoch 29, 50% 	 train_loss: 0.47 took: 45.40s
# Epoch 29, 61% 	 train_loss: 0.50 took: 45.67s
# Epoch 29, 71% 	 train_loss: 0.48 took: 45.19s
# Epoch 29, 81% 	 train_loss: 0.52 took: 45.30s
# Epoch 29, 91% 	 train_loss: 0.51 took: 45.25s
# Validation loss = 0.83
# Epoch 30, 10% 	 train_loss: 0.46 took: 46.20s
# Epoch 30, 20% 	 train_loss: 0.49 took: 45.45s
# Epoch 30, 30% 	 train_loss: 0.46 took: 45.38s
# Epoch 30, 40% 	 train_loss: 0.46 took: 45.17s
# Epoch 30, 50% 	 train_loss: 0.53 took: 45.24s
# Epoch 30, 61% 	 train_loss: 0.48 took: 45.64s
# Epoch 30, 71% 	 train_loss: 0.53 took: 45.25s
# Epoch 30, 81% 	 train_loss: 0.44 took: 45.28s
# Epoch 30, 91% 	 train_loss: 0.51 took: 45.15s
# Validation loss = 0.85
# Epoch 31, 10% 	 train_loss: 0.49 took: 46.00s
# Epoch 31, 20% 	 train_loss: 0.52 took: 45.28s
# Epoch 31, 30% 	 train_loss: 0.50 took: 45.03s
# Epoch 31, 40% 	 train_loss: 0.52 took: 45.01s
# Epoch 31, 50% 	 train_loss: 0.46 took: 45.08s
# Epoch 31, 61% 	 train_loss: 0.51 took: 45.27s
# Epoch 31, 71% 	 train_loss: 0.47 took: 44.99s
# Epoch 31, 81% 	 train_loss: 0.51 took: 45.07s
# Epoch 31, 91% 	 train_loss: 0.50 took: 45.20s
# Validation loss = 0.83
# Epoch 32, 10% 	 train_loss: 0.46 took: 46.24s
# Epoch 32, 20% 	 train_loss: 0.46 took: 45.48s
# Epoch 32, 30% 	 train_loss: 0.46 took: 45.34s
# Epoch 32, 40% 	 train_loss: 0.47 took: 45.36s
# Epoch 32, 50% 	 train_loss: 0.47 took: 45.39s
# Epoch 32, 61% 	 train_loss: 0.46 took: 45.55s
# Epoch 32, 71% 	 train_loss: 0.45 took: 45.28s
# Epoch 32, 81% 	 train_loss: 0.46 took: 45.37s
# Epoch 32, 91% 	 train_loss: 0.50 took: 45.55s
# Validation loss = 0.83
# Epoch 33, 10% 	 train_loss: 0.47 took: 45.99s
# Epoch 33, 20% 	 train_loss: 0.46 took: 45.47s
# Epoch 33, 30% 	 train_loss: 0.43 took: 45.27s
# Epoch 33, 40% 	 train_loss: 0.45 took: 45.20s
# Epoch 33, 50% 	 train_loss: 0.44 took: 45.21s
# Epoch 33, 61% 	 train_loss: 0.50 took: 45.46s
# Epoch 33, 71% 	 train_loss: 0.46 took: 45.30s
# Epoch 33, 81% 	 train_loss: 0.45 took: 45.16s
# Epoch 33, 91% 	 train_loss: 0.49 took: 45.51s
# Validation loss = 0.78
# Epoch 34, 10% 	 train_loss: 0.46 took: 45.92s
# Epoch 34, 20% 	 train_loss: 0.44 took: 45.37s
# Epoch 34, 30% 	 train_loss: 0.44 took: 45.13s
# Epoch 34, 40% 	 train_loss: 0.42 took: 45.11s
# Epoch 34, 50% 	 train_loss: 0.44 took: 45.11s
# Epoch 34, 61% 	 train_loss: 0.43 took: 45.33s
# Epoch 34, 71% 	 train_loss: 0.48 took: 45.01s
# Epoch 34, 81% 	 train_loss: 0.48 took: 45.13s
# Epoch 34, 91% 	 train_loss: 0.43 took: 45.52s
# Validation loss = 0.84
# Epoch 35, 10% 	 train_loss: 0.45 took: 45.99s
# Epoch 35, 20% 	 train_loss: 0.42 took: 45.40s
# Epoch 35, 30% 	 train_loss: 0.45 took: 45.20s
# Epoch 35, 40% 	 train_loss: 0.45 took: 45.20s
# Epoch 35, 50% 	 train_loss: 0.42 took: 45.12s
# Epoch 35, 61% 	 train_loss: 0.47 took: 45.40s
# Epoch 35, 71% 	 train_loss: 0.46 took: 45.11s
# Epoch 35, 81% 	 train_loss: 0.46 took: 45.26s
# Epoch 35, 91% 	 train_loss: 0.45 took: 45.30s
# Validation loss = 0.87
# Epoch 36, 10% 	 train_loss: 0.45 took: 45.92s
# Epoch 36, 20% 	 train_loss: 0.39 took: 45.64s
# Epoch 36, 30% 	 train_loss: 0.40 took: 45.27s
# Epoch 36, 40% 	 train_loss: 0.42 took: 45.15s
# Epoch 36, 50% 	 train_loss: 0.46 took: 45.52s
# Epoch 36, 61% 	 train_loss: 0.47 took: 45.22s
# Epoch 36, 71% 	 train_loss: 0.43 took: 45.20s
# Epoch 36, 81% 	 train_loss: 0.44 took: 45.34s
# Epoch 36, 91% 	 train_loss: 0.46 took: 45.47s
# Validation loss = 0.85
# Epoch 37, 10% 	 train_loss: 0.44 took: 46.05s
# Epoch 37, 20% 	 train_loss: 0.38 took: 45.58s
# Epoch 37, 30% 	 train_loss: 0.41 took: 45.24s
# Epoch 37, 40% 	 train_loss: 0.42 took: 45.12s
# Epoch 37, 50% 	 train_loss: 0.38 took: 45.54s
# Epoch 37, 61% 	 train_loss: 0.42 took: 45.27s
# Epoch 37, 71% 	 train_loss: 0.48 took: 45.11s
# Epoch 37, 81% 	 train_loss: 0.49 took: 45.16s
# Epoch 37, 91% 	 train_loss: 0.44 took: 45.36s
# Validation loss = 0.84
# Epoch 38, 10% 	 train_loss: 0.40 took: 45.95s
# Epoch 38, 20% 	 train_loss: 0.41 took: 45.62s
# Epoch 38, 30% 	 train_loss: 0.42 took: 45.28s
# Epoch 38, 40% 	 train_loss: 0.42 took: 45.23s
# Epoch 38, 50% 	 train_loss: 0.44 took: 45.55s
# Epoch 38, 61% 	 train_loss: 0.42 took: 45.14s
# Epoch 38, 71% 	 train_loss: 0.39 took: 45.33s
# Epoch 38, 81% 	 train_loss: 0.43 took: 45.33s
# Epoch 38, 91% 	 train_loss: 0.43 took: 45.48s
# Validation loss = 0.86
# Epoch 39, 10% 	 train_loss: 0.40 took: 46.02s
# Epoch 39, 20% 	 train_loss: 0.41 took: 45.50s
# Epoch 39, 30% 	 train_loss: 0.43 took: 45.11s
# Epoch 39, 40% 	 train_loss: 0.39 took: 45.08s
# Epoch 39, 50% 	 train_loss: 0.41 took: 45.53s
# Epoch 39, 61% 	 train_loss: 0.43 took: 45.15s
# Epoch 39, 71% 	 train_loss: 0.48 took: 45.12s
# Epoch 39, 81% 	 train_loss: 0.43 took: 45.11s
# Epoch 39, 91% 	 train_loss: 0.43 took: 45.39s
# Validation loss = 0.90
# Epoch 40, 10% 	 train_loss: 0.40 took: 46.06s
# Epoch 40, 20% 	 train_loss: 0.38 took: 45.63s
# Epoch 40, 30% 	 train_loss: 0.39 took: 45.22s
# Epoch 40, 40% 	 train_loss: 0.37 took: 45.13s
# Epoch 40, 50% 	 train_loss: 0.38 took: 45.51s
# Epoch 40, 61% 	 train_loss: 0.42 took: 45.03s
# Epoch 40, 71% 	 train_loss: 0.40 took: 45.15s
# Epoch 40, 81% 	 train_loss: 0.43 took: 45.07s
# Epoch 40, 91% 	 train_loss: 0.42 took: 45.47s
# Validation loss = 0.85
# Training Finished, took 19400.93s

# %% [markdown]
# ### Losses Plot

# %%
plot_losses(train_history, val_history)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Accuracy of the trained model

# %%
compute_accuracy(net)
# Out:
# Accuracy of the network on the 20000 train images: 83.42 %
# Accuracy of the network on the 5000 validation images: 75.80 %
# Accuracy of the network on the 5000 test images: 73.52 %

# %% [markdown]
# **Baseline: Simple Convolutional Neural Network (form part II)**
#
# <table>
# <tr>
#     <td>Accuracy on the test set:</td>
#     <td>60.80 %</td>
# </tr>
# </table>

# %%
confusion_matrix = accuracy_per_class(net)
# Out:
# Class      Accuracy (%)
# plane        80.12
# car          82.57
# bird         57.81
# cat          63.98
# deer         55.23
# dog          50.41
# frog         65.38
# horse        64.44
# ship         76.79
# truck        79.73

# %%
#plot_confusion_matrix(confusion_matrix, classes,
#                      title='Confusion matrix, without normalization')
# Plot normalized confusion matrix
plot_confusion_matrix(confusion_matrix, classes, normalize=True,
                      title='Normalized confusion matrix')

# %% [markdown]
# ### Going further
#
# - [Coursera Course on CNN](https://www.coursera.org/learn/convolutional-neural-networks)
# - [Standford Course](http://cs231n.stanford.edu/syllabus.html)
# - [PyTorch Tutorial](http://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html)
